# %% [markdown]
# ## Coverage calculations
#
# All files on farm in `/home/ctbrown/scratch3/2025-workflow-core99/`

# %%
# base checkout of workflow directory is here:
BASE='/home/ctbrown/scratch3/2025-workflow-core99/'

# outputs from running `do_mapping`:
BASE_OUTPUTS=BASE+'/outputs.mapping/bams.cds.rand'

# where to place figures
FIG_OUT=BASE+'/outputs.figures/'

# %%
import polars as pl
import numpy as np
import matplotlib.pyplot as plt
import scipy
import math
import sourmash
import collections

import seaborn as sns
from matplotlib.legend_handler import HandlerTuple

# %%
NAMES = [ x.strip() for x in open(BASE+'/inputs.cds/names-plus.list') ]
print(f'loaded {len(NAMES)} species names')

SPECIAL = [ x.strip() for x in open(BASE+'/inputs.cds/names.list') ]
print(f'loaded {len(NAMES)} special species names')

NAMES.sort()
NAMES
# Out:
# loaded 27 species names
# loaded 27 special species names
# ['s__Bariatricus sp004560705',
#  's__Bifidobacterium thermacidophilum',
#  's__Blautia_A sp945872375',
#  's__CAG-269 sp014846485',
#  's__CAG-465 sp000433755',
#  's__CAG-873 sp016302215',
#  's__Colivicinus sp002299675',
#  's__Cryptobacteroides sp000432655',
#  's__Cryptobacteroides sp000434935',
#  's__Cryptobacteroides sp034089285',
#  's__Cryptobacteroides sp900546925',
#  's__Fimisoma sp002320005',
#  's__Floccifex porci',
#  's__JAFBIX01 sp021531895',
#  's__Lactobacillus amylovorus',
#  's__Mogibacterium_A kristiansenii',
#  's__Ornithospirochaeta sp022785155',
#  's__Phascolarctobacterium_A succinatutens_B',
#  's__Prevotella sp000434975',
#  's__Prevotella sp002251295',
#  's__Ruminococcoides sp902766885',
#  's__Ruminococcus_C sp000433635',
#  's__SIG351 sp945918795',
#  's__Sodaliphilus sp004557565',
#  's__UBA2868 sp004552595',
#  's__UMGS1225 sp034086705',
#  's__Ventricola sp017937505']

# %% [markdown]
# ## Load manysearch of all species against 3,216 metagenomes
#
# & rename columns etc etc.

# %%
manysearch_df = pl.read_csv('../outputs.cds/cds3/manysearch.cds3.3216.csv').with_columns(
    pl.col("query_name").alias("species"),
    pl.col("match_name").alias("metag"),
    (pl.col("intersect_hashes") * pl.col("scaled") / pl.col("containment")).alias("sketch_size"),
)

# %%
manysearch_df
# Out:
# shape: (82_555, 23)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ query_nam ┆ query_md5 ┆ match_nam ┆ containme ┆ … ┆ total_wei ┆ species   ┆ metag     ┆ sketch_s │
# │ e         ┆ ---       ┆ e         ┆ nt        ┆   ┆ ghted_has ┆ ---       ┆ ---       ┆ ize      │
# │ ---       ┆ str       ┆ ---       ┆ ---       ┆   ┆ hes       ┆ str       ┆ str       ┆ ---      │
# │ str       ┆           ┆ str       ┆ f64       ┆   ┆ ---       ┆           ┆           ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆ i64       ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │
      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ s__SIG351 ┆ deae0769a ┆ ERR831478 ┆ 0.095602  ┆ … ┆ 11178711  ┆ s__SIG351 ┆ ERR831478 ┆ 1.569e6  │
# │ sp9459187 ┆ 7f1129574 ┆ 4         ┆           ┆   ┆           ┆ sp9459187 ┆ 4         ┆          │
# │ 95        ┆ 65b790cea ┆           ┆           ┆   ┆           ┆ 95        ┆           ┆          │
# │           ┆ ca8…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ s__Lactob ┆ 126daabd3 ┆ ERR831478 ┆ 0.112227  ┆ … ┆ 11178711  ┆ s__Lactob ┆ ERR831478 ┆ 3.983e6  │
# │ acillus   ┆ e4858fd7f ┆ 4         ┆           ┆   ┆           ┆ acillus   ┆ 4         ┆          │
# │ amylovoru ┆ 57ebee5c0 ┆           ┆           ┆   ┆           ┆ amylovoru ┆           ┆          │
# │ s         ┆ 7f5…      ┆           ┆           ┆   ┆           ┆ s         ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ## Convert columns from hashes into bp

# %%
manysearch_df = manysearch_df.with_columns(
    (pl.col('intersect_hashes')*1000).alias('intersect_bp'),
    (pl.col('n_weighted_found')*1000).alias('weighted_bp'),
)

# %% [markdown]
# ## Build a basic coverage curve function
#
# $$y = G (1 - e^{(-Cx)})$$
#
# G is the genome size, C is the coverage exponent.

# %%
def coverage_curve(x, G, C):
    return G*(1 - np.exp(-C*x))

# %%
x = np.arange(1, 1000)
y = [ coverage_curve(xx, 100, .01) for xx in x ]
plt.plot(x, y)
plt.xlabel('depth')
plt.ylabel('breadth')
plt.title("example coverage curve")
# Out:
# Text(0.5, 1.0, 'example coverage curve')

# %% [markdown]
# ## Build a fit function that takes weighted bp (x) and containment (y) and fits to a coverage curve

# %%
def do_fit(contain_df, *, fn=coverage_curve, p0=None):
    "Fit to given function, which takes two parameters, G and C. Return fit values & params."
    if p0 is None:
        p0 = (max(contain_df['weighted_bp']), .001)
    popt, pcov = scipy.optimize.curve_fit(fn, contain_df['weighted_bp'], contain_df['intersect_bp'], p0)
    G, C = popt

    y = np.asarray(contain_df['weighted_bp'])
    yfit = coverage_curve(y, G, C)

    # residual sum of squares
    ss_res = np.sum((y - yfit) ** 2)
    # total sum of squares
    ss_tot = np.sum((y - np.mean(y)) ** 2)
    # r-squared
    r2 = 1 - (ss_res / ss_tot)

    return yfit, (G, C), r2

# %%
# test fit function!
name = NAMES[0]
print('fitting for:', NAMES[0])
species_df = manysearch_df.filter(pl.col("species") == NAMES[0]).sort(by='weighted_bp')

yfit, (G, C), r2 = do_fit(species_df)
print(f"fit params for {name}: G={G:.0f} C={C}; r2={r2:.3f}")
plt.plot(species_df['weighted_bp'], species_df['intersect_bp'], 'b*')
plt.plot(species_df['weighted_bp'], yfit, 'o--')
plt.title(name)
# Out:
# fitting for: s__Bariatricus sp004560705
# fit params for s__Bariatricus sp004560705: G=1043049 C=6.186134960198795e-07; r2=-0.104
# /group/datalabgrp/ctbrown/2025-grist-annie/.snakemake/conda/ab4c18c32e39b7f9ba11a10bc8c18bcf_/lib/python3.12/site-packages/polars/series/series.py:1571: RuntimeWarning: overflow encountered in exp
#   lambda out: ufunc(*args, out=out, dtype=dtype_char, **kwargs),
# /group/datalabgrp/ctbrown/2025-grist-annie/.snakemake/conda/ab4c18c32e39b7f9ba11a10bc8c18bcf_/lib/python3.12/site-packages/polars/series/series.py:1571: RuntimeWarning: overflow encountered in multiply
#   lambda out: ufunc(*args, out=out, dtype=dtype_char, **kwargs),
# Text(0.5, 1.0, 's__Bariatricus sp004560705')

# %%
# test fit function!
name = NAMES[0]
print('fitting for:', NAMES[0])
species_df = manysearch_df.filter(pl.col("species") == NAMES[0]).sort(by='weighted_bp', descending=True)
species_df = species_df.tail(int(0.8 * len(species_df)))

#yfit, (G, C), r2 = do_fit(species_df)
#print(f"fit params for {name}: G={G:.0f} C={C}; r2={r2:.3f}")

def do_fit_split(xl, yl, *, fn=coverage_curve, p0=None):
    "Fit to given function, which takes two parameters, G and C. Return fit values & params."
    if p0 is None:
        p0 = (max(xl), .001)
    popt, pcov = scipy.optimize.curve_fit(fn, xl, yl, p0)
    G, C = popt

    y = np.asarray(xl)
    yfit = coverage_curve(y, G, C)

    # residual sum of squares
    ss_res = np.sum((y - yfit) ** 2)
    # total sum of squares
    ss_tot = np.sum((y - np.mean(y)) ** 2)
    # r-squared
    r2 = 1 - (ss_res / ss_tot)

    return yfit, (G, C), r2

def bin_by_threshold(xl, yl, *, threshold):
    x2 = []
    y2 = []

    xy = list(zip(xl, yl))
    i = 0
    while xy[i][1] > threshold:
        x, y = xy[i]
        x2.append(x)
        y2.append(y)
        print(y)
        i += 1

    coll_x = []
    coll_y = []
    while i < len(xy):
        x, y = xy[i]
        coll_x.append(x)
        coll_y.append(y)
        if sum(coll_y) > threshold:
            x = sum(coll_x) / len(coll_x)
            y = sum(coll_y) / len(coll_y)
            x2.append(x)
            y2.append(y)

            coll_x = []
            coll_y = []
        i += 1

    if coll_x:
        x = sum(coll_x) / len(coll_x)
        y = sum(coll_y) / len(coll_y)
        x2.append(x)
        y2.append(y)
    
    return x2, y2

yfit, (G, C), r2 = do_fit(species_df)

xx, yy = bin_by_threshold(species_df['weighted_bp'].to_list(), species_df['intersect_bp'].to_list(),
                         threshold=2e6)
yfit2, (G2, C2), r2 = do_fit_split(xx, yy)
print('ZZ 0', len(species_df), len(xx))
print('ZZ 1', G, C)
print('ZZ 2', G2, C2)
print('ZZ 3', G - G2, C - C2)


fig, axes= plt.subplots(nrows=1, ncols=3, figsize=(12, 4))
ax = axes[0]
ax.plot(species_df['weighted_bp'], species_df['intersect_bp'], 'b*')
ax.plot(xx, yy, 'ro', alpha=0.2)
ax.plot(xx, yfit2, 'g-')
ax.set_xscale('log')

ax = axes[1]
ax.plot(species_df['weighted_bp'], species_df['intersect_bp'], 'b*')
ax.plot(xx, yy, 'ro', alpha=0.2)
ax.plot(xx, yfit2, 'g-')

ax = axes[2]
ax.plot(species_df['weighted_bp'], species_df['intersect_bp'], 'b*')
ax.set_xlim(0, 5e5)
ax.plot(xx, yy, 'ro', alpha=0.2)
ax.plot(species_df['weighted_bp'], yfit, 'g-')
# Out:
# fitting for: s__Bariatricus sp004560705
# ZZ 0 2568 468
# ZZ 1 916637.4845423587 7.901912359876891e-07
# ZZ 2 911153.4827182954 8.065649102438196e-07
# ZZ 3 5484.001824063249 -1.6373674256130554e-08
# /tmp/ipykernel_1816696/4248317731.py:2: RuntimeWarning: overflow encountered in exp
#   return G*(1 - np.exp(-C*x))
# /tmp/ipykernel_1816696/4248317731.py:2: RuntimeWarning: overflow encountered in multiply
#   return G*(1 - np.exp(-C*x))

# %% [markdown]
# ## Run fit function for all species, and record parameters.

# %%
params_d = {}
params_df = []

for name in NAMES:
    species_df = manysearch_df.filter(pl.col("species") == name).sort(by='weighted_bp', descending=True)
    species_df = species_df.tail(2000)
    print('XX', len(species_df))
    try:
        yfit, params, r2 = do_fit(species_df)
    except:
        print('FAIL', name)
        continue
    (GSIZE, CEXP) = params
    params_d[name] = (GSIZE, CEXP, r2)
    med = np.median(species_df['weighted_bp'] / GSIZE)
    q25 = np.percentile(species_df['weighted_bp'] / GSIZE, .25)
    num_metag = len(species_df.filter(pl.col("intersect_bp") > 20000))
#    print(f"{name:<50} {GSIZE / 1e6:.1f} Mbp    {med:.2f}        {EXP}")
    params_df.append(dict(name=name, med=med, gsize=GSIZE, exp=CEXP, num_metag=num_metag, r2=r2, q25=q25))

    plt.plot(species_df['weighted_bp'], species_df['intersect_bp'], '*', label='data')
    plt.plot(species_df['weighted_bp'], yfit, '*', alpha=0.5, label='fit')
    plt.tight_layout()
    if name in SPECIAL:
        plt.title('*' + name)
    else:
        plt.title(name)
    plt.xlabel('weighted_bp')
    plt.ylabel('intersect_bp')
    plt.legend(loc='lower right')

    #plt.xlim(0, 3)
    #plt.ylim(0, 1.5)
    plt.show()

params_df = pl.DataFrame(params_df)
# Out:
# XX 2000
# XX 2000
# FAIL s__Bifidobacterium thermacidophilum
# XX 2000
# XX 2000
# XX 2000
# XX 2000
# FAIL s__CAG-873 sp016302215
# XX 2000
# XX 2000
# XX 2000
# XX 2000
# XX 2000
# XX 2000
# XX 2000
# XX 2000
# XX 2000
# XX 2000
# XX 2000
# XX 2000
# XX 2000
# XX 2000
# XX 2000
# XX 2000
# XX 2000
# FAIL s__SIG351 sp945918795
# XX 2000
# XX 2000
# XX 2000
# XX 2000

# %%
print("species                                     med cov       q25           gsize")
for row in params_df.sort(by='med').iter_rows(named=True):
    name, med, gsize, num_metag, r2, q25 = row["name"], row["med"], row["gsize"], row["num_metag"], row["r2"], row['q25']
    print(f"{name:<45} {med:<10.2f}  {q25:<10.4f}   {gsize/1e6:.1f}Mbp     in {num_metag}    {r2:.3f}")
# Out:
# species                                     med cov       q25           gsize
# s__Blautia_A sp945872375                      0.01        0.0017       0.6Mbp     in 478    0.932
# s__Ruminococcus_C sp000433635                 0.02        0.0013       0.8Mbp     in 758    0.790
# s__CAG-269 sp014846485                        0.03        0.0037       0.3Mbp     in 526    0.841
# s__UMGS1225 sp034086705                       0.06        0.0010       1.0Mbp     in 1441    0.891
# s__CAG-465 sp000433755                        0.06        0.0100       0.1Mbp     in 87    0.699
# s__Ventricola sp017937505                     0.07        0.0081       0.1Mbp     in 368    0.802
# s__JAFBIX01 sp021531895                       0.10        0.0010       2.0Mbp     in 1873    0.671
# s__UBA2868 sp004552595                        0.15        0.0007       4.4Mbp     in 1894    0.073
# s__Cryptobacteroides sp000434935              0.19        0.0010       1.0Mbp     in 1821    0.701
# s__Ruminococcoides sp902766885                0.23        0.0322       0.0Mbp     in 6    0.574
# s__Prevotella sp000434975                     0.24        0.0030       0.7Mbp     in 1787    0.451
# s__Ornithospirochaeta sp022785155             0.31        0.0007       1.3Mbp     in 1864    0.640
# s__Phascolarctobacterium_A succinatutens_B    0.32        0.0401       0.0Mbp     in 1    0.574
# s__Floccifex porci                            0.34        0.0009       1.1Mbp     in 1892    0.395
# s__Fimisoma sp002320005                       0.34        0.0011       0.9Mbp     in 1910    0.557
# s__Colivicinus sp002299675                    0.35        0.0007       1.5Mbp     in 1862    0.519
# s__Cryptobacteroides sp000432655              0.35        0.0008       1.2Mbp     in 1846    0.445
# s__Cryptobacteroides sp034089285              0.44        0.0028       0.7Mbp     in 1903    0.349
# s__Bariatricus sp004560705                    0.54        0.0021       0.9Mbp     in 1861    0.229
# s__Cryptobacteroides sp900546925              0.59        0.0017       1.2Mbp     in 1928    0.155
# s__Prevotella sp002251295                     0.59        0.0018       1.1Mbp     in 1884    0.211
# s__Mogibacterium_A kristiansenii              1.04        0.0052       0.4Mbp     in 1908    -0.235
# s__Sodaliphilus sp004557565                   1.96        0.0022       1.8Mbp     in 1967    -0.757
# s__Lactobacillus amylovorus                   3.50        0.0130       0.3Mbp     in 1951    -0.974

# %% [markdown]
# ## Update with a new fit function that we have an estimated genome size
#
# We can now adjust 'x' by the estimated size of the (pan) genome, for each species.
#
# Read through [the inStrain docs](https://instrain.readthedocs.io/en/latest/important_concepts.html) for some interesting context -
# the coverage parameter should be ~0.88 for a full genome.

# %%
# try with adjusted coverage, where we divide 'x' by tbe estimated genome size
params2_d = {}
for name in NAMES:
    if name not in params_d:
        print('SKIP:', name)
        continue
    species_df = manysearch_df.filter(pl.col("species") == name).sort(by='weighted_bp', descending=True)
    species_df = species_df.tail(2000)
    GSIZE, EXP, r2 = params_d[name]

    def adj_coverage_curve(x, c, e):
        return c*(1 - np.exp(-e*x/GSIZE))

    p0 = (max(species_df['weighted_bp']), 0.9)
    _, params2, _ = do_fit(species_df, fn=adj_coverage_curve, p0=p0)
    NORM, EXP2 = params2
    print(f"{name:<50} {NORM:<10.0f} {EXP2:2f}")
    params2_d[name] = params2
# Out:
# s__Bariatricus sp004560705                         947051     0.714944
# SKIP: s__Bifidobacterium thermacidophilum
# s__Blautia_A sp945872375                           587557     0.831832
# s__CAG-269 sp014846485                             268415     0.776130
# s__CAG-465 sp000433755                             100323     0.679357
# SKIP: s__CAG-873 sp016302215
# s__Colivicinus sp002299675                         1504067    0.773820
# s__Cryptobacteroides sp000432655                   1178592    0.720171
# s__Cryptobacteroides sp000434935                   1000829    0.793196
# s__Cryptobacteroides sp034089285                   718010     0.723799
# s__Cryptobacteroides sp900546925                   1161355    0.672876
# s__Fimisoma sp002320005                            872514     0.803250
# s__Floccifex porci                                 1119260    0.690207
# s__JAFBIX01 sp021531895                            1989249    0.692652
# s__Lactobacillus amylovorus                        307596     0.368097
# s__Mogibacterium_A kristiansenii                   383256     0.576762
# s__Ornithospirochaeta sp022785155                  1348176    0.844105
# s__Phascolarctobacterium_A succinatutens_B         24958      0.809940
# s__Prevotella sp000434975                          664118     0.671335
# s__Prevotella sp002251295                          1132404    0.757838
# s__Ruminococcoides sp902766885                     31019      0.741984
# s__Ruminococcus_C sp000433635                      764743     0.689338
# SKIP: s__SIG351 sp945918795
# s__Sodaliphilus sp004557565                        1847423    0.579670
# s__UBA2868 sp004552595                             4365129    0.363018
# s__UMGS1225 sp034086705                            1007622    0.838180
# s__Ventricola sp017937505                          122775     0.770041

# %%
# use the new information to estimate breadth and depth for every row, and then add into data frame.
adj_df = []

for row in manysearch_df.iter_rows(named=True):
    species = row["species"]
    metag = row["metag"]
    intersect_bp = row["intersect_bp"]
    weighted_bp = row["weighted_bp"]
    if species not in params_d:
        continue

    GSIZE, EXP, r2 = params_d[species]
    breadth = intersect_bp / GSIZE
    depth = weighted_bp / GSIZE
    fit_breadth = coverage_curve(weighted_bp, GSIZE, EXP) / GSIZE
    adj_df.append(dict(species=species, metag=metag, breadth=breadth, depth=depth, fit_breadth=fit_breadth))

adj_df = pl.DataFrame(adj_df)
join_df = manysearch_df.join(adj_df, on=['species', 'metag'], how='inner')
join_df
# Out:
# shape: (73_755, 28)
# ┌────────────┬───────────┬───────────┬───────────┬───┬───────────┬──────────┬──────────┬───────────┐
# │ query_name ┆ query_md5 ┆ match_nam ┆ containme ┆ … ┆ weighted_ ┆ breadth  ┆ depth    ┆ fit_bread │
# │ ---        ┆ ---       ┆ e         ┆ nt        ┆   ┆ bp        ┆ ---      ┆ ---      ┆ th        │
# │ str        ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ f64      ┆ f64      ┆ ---       │
# │            ┆           ┆ str       ┆ f64       ┆   ┆ i64       ┆          ┆          ┆ f64       │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪══════════╪══════════╪═══════════╡
# │ s__Cryptob ┆ 33ab31888 ┆ SRR111254 ┆ 0.045958  ┆ … ┆ 259000    ┆ 0.162058 ┆ 0.219754 ┆ 0.146372  │
# │ acteroides ┆ 6b78679c8 ┆ 36        ┆           ┆   ┆           ┆          ┆          ┆           │
# │ sp0004326… ┆ de5e106ac ┆           ┆           ┆   ┆           ┆          ┆          ┆           │
# │            ┆ 6b9…      ┆           ┆           ┆   ┆           ┆          ┆          ┆           │
# │ s__Bariatr ┆ a053514b9 ┆ SRR111254 ┆ 0.127554  ┆ … ┆ 680000    ┆ 0.408637 ┆ 0.718018 ┆ 0.401508  │
# │ icus sp004 ┆ 87f8c11e2 ┆ 36        ┆           ┆   ┆           ┆          ┆          ┆           │
# │ 560705     ┆ ed518938e ┆           ┆           ┆   ┆           ┆          ┆          ┆           │
# │            ┆
┆           │
# └────────────┴───────────┴───────────┴───────────┴───┴───────────┴──────────┴──────────┴───────────┘

# %%
for name in NAMES:
    species_df = join_df.filter(pl.col("species") == name)

    plt.plot(species_df['depth'], species_df['breadth'], '*', label='data')
    plt.plot(species_df['depth'], species_df['fit_breadth'], '*', alpha=0.5, label='fit')
    plt.tight_layout()
    if name in SPECIAL:
        plt.title('*' + name)
    else:
        plt.title(name)
    plt.xlabel('depth (coverage)')
    plt.ylabel('breadth (detection)')
    plt.legend(loc='lower right')

    #plt.xlim(0, 3)
    #plt.ylim(0, 1.5)
    plt.show()

# %%
for name in NAMES:
    species_df = join_df.filter(pl.col("species") == name)
    if name not in params_d:
        continue
    GSIZE, EXP, r2 = params_d[name]

    plt.plot(species_df['weighted_bp'] / GSIZE, species_df['intersect_bp'] / GSIZE, '*')
    plt.tight_layout()
    if name in SPECIAL:
        plt.title('**' + name)
    else:
        plt.title(name)
    plt.xlabel('coverage-ish')
    plt.ylabel('isect k-mers')

    yfit = coverage_curve(species_df['weighted_bp'], GSIZE, EXP)
    plt.plot(species_df['weighted_bp'] / GSIZE, yfit / GSIZE, 'o', alpha=0.5)
    plt.xlim(0, 3)
    plt.show()

# %% [markdown]
# ### Export / save k-mer coverage information

# %%
join_df.write_csv('../outputs.cds/kmer-coverage.csv')

# %% [markdown]
# ## Can we correlate with metagenome sequencing depth?
#
# Answer: no, not really. Presumably biology is involved (that is, actual abundance of microbes is different in different metagenomes!)

# %%
metadata_df = pl.scan_parquet('/group/ctbrowngrp5/sra-metagenomes/20241128-metadata.parquet')
metadata_df = metadata_df.select(["acc", "organism", "assay_type", "mbases"])\
    .filter(pl.col("acc") != "NP")\
    .filter(pl.col("assay_type") == "WGS")

metadata_df = metadata_df.collect()
metadata_df
# Out:
# shape: (703_916, 4)
# ┌─────────────┬───────────────────────┬────────────┬────────┐
# │ acc         ┆ organism              ┆ assay_type ┆ mbases │
# │ ---         ┆ ---                   ┆ ---        ┆ ---    │
# │ str         ┆ str                   ┆ str        ┆ i64    │
# ╞═════════════╪═══════════════════════╪════════════╪════════╡
# │ SRR28523869 ┆ human metagenome      ┆ WGS        ┆ 258    │
# │ SRR19901137 ┆ Streptococcus suis    ┆ WGS        ┆ 40     │
# │ SRR24962475 ┆ Escherichia coli      ┆ WGS        ┆ 88     │
# │ SRR29161330 ┆ biofilm metagenome    ┆ WGS        ┆ 3      │
# │ SRR26668739 ┆ bovine gut metagenome ┆ WGS        ┆ 129    │
# │ …           ┆ …                     ┆ …          ┆ …      │
# │ ERR4174288  ┆ human gut metagenome  ┆ WGS        ┆ 1017   │
# │ ERR3160109  ┆ human gut metagenome  ┆ WGS        ┆ 133    │
# │ ERR2709457  ┆ human gut metagenome  ┆ WGS        ┆ 964    │
# │ ERR2709367  ┆ human gut metagenome  ┆ WGS        ┆ 56     │
# │ ERR2709388  ┆ human gut metagenome  ┆ WGS        ┆ 411    │
# └─────────────┴───────────────────────┴────────────┴────────┘

# %%
for name in sorted(NAMES):
    species_df = join_df.filter(pl.col("species") == name)
    foo_df = species_df.join(metadata_df, left_on='metag', right_on='acc', how='inner')
    plt.plot(foo_df['depth'], foo_df['mbases'], '*', alpha=0.5)
    plt.xlabel('predicted coverage (depth)')
    plt.ylabel('mbases sequenced')
    plt.tight_layout()
    if name in SPECIAL:
        plt.title('**' + name)
    else:
        plt.title(name)
    plt.xlim(0, 20)
    plt.show()

# %% [markdown]
# ## Extract high coverage metagenomes for core species

# %%
highcov_metags = set()
for name in SPECIAL:
    species_df = join_df.filter(pl.col("species") == name).sort(by='depth', descending=True).head(10)
    highcov_metags.update(species_df['match_name'])

print(len(highcov_metags))
print(highcov_metags)
# Out:
# 124
# {'SRR8960083', 'SRR8960608', 'SRR8960810', 'SRR17241500', 'SRR14369236', 'SRR17241565', 'SRR8960113', 'SRR8960206', 'SRR17241669', 'SRR17241646', 'SRR8960383', 'SRR12795793', 'SRR11185234', 'SRR8960774', 'SRR17241658', 'SRR11489748', 'SRR12795792', 'SRR11489789', 'SRR12799829', 'SRR17241654', 'SRR17241664', 'SRR12795744', 'SRR8960590', 'SRR17241636', 'SRR18048906', 'SRR17241686', 'SRR17241612', 'SRR17241488', 'SRR11489780', 'SRR11185253', 'SRR17241643', 'SRR11185229', 'SRR11185243', 'SRR17241672', 'SRR11185230', 'SRR11551369', 'SRR11489785', 'SRR17241569', 'SRR8960309', 'SRR8960079', 'SRR14369185', 'SRR8960090', 'ERR1135271', 'SRR17241490', 'SRR17241521', 'SRR16235689', 'SRR11185225', 'SRR17241614', 'SRR17241677', 'SRR8960205', 'SRR17241547', 'SRR11185261', 'SRR11185237', 'SRR11489783', 'SRR8960216', 'SRR17241613', 'SRR5666656', 'SRR17241688', 'SRR11185255', 'SRR17241575', 'SRR11185247', 'SRR5240744', 'SRR17241639', 'SRR17241632', 'SRR18048905', 'SRR7182044', 'SRR8960963', 'SRR8960711', 'SRR17241656', 'SRR17241561', 'SRR8960339', 'SRR8960716', 'SRR17241663', 'SRR17241694', 'SRR17241649', 'SRR17241660', 'SRR11185238', 'SRR12799828', 'SRR8960802', 'SRR11185232', 'SRR17241620', 'SRR16235702', 'SRR11489778', 'SRR8960430', 'SRR8960670', 'SRR17241505', 'SRR11185263', 'SRR11185241', 'SRR17241640', 'SRR8960176', 'SRR8960439', 'SRR11489791', 'SRR8960441', 'SRR8960924', 'SRR11489769', 'SRR11185262', 'SRR18048908', 'SRR8960211', 'SRR17241618', 'SRR17241601', 'SRR17241494', 'SRR8960204', 'SRR11185246', 'SRR17241501', 'SRR17241606', 'SRR17241627', 'SRR17241550', 'SRR11185260', 'SRR17241499', 'SRR12799827', 'SRR11489784', 'SRR17241642', 'SRR8960514', 'SRR17241638', 'SRR11489790', 'SRR16235687', 'SRR17241631', 'SRR17241497', 'SRR18048907', 'SRR17241585', 'SRR8960438', 'SRR14369266', 'SRR17241520', 'SRR8960376'}

# %%
rand_metags = set([ x.strip() for x in open('../inputs.cds/rand_subset.3216.100.txt') ])
print(rand_metags.intersection(highcov_metags))
highcov_metags -= rand_metags
# Out:
# {'SRR12795793', 'SRR17241663', 'SRR5240744', 'SRR8960309', 'SRR11489769', 'SRR17241521', 'SRR11489783'}

# %%
with open('../outputs.cds/highcov-metags.txt', 'wt') as fp:
    fp.write("\n".join(highcov_metags))
