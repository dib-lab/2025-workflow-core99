# %% [markdown]
# # Parse and aggregate singleM and sourmash results for metagenome x species reads.
#
# Questions we are asking:
#
# ## Q1: is there a lot of Artiodactyla contamination in the reads that map to pangenomes?
#
# Logic: suppose the pangenome contains cryptic Artiodactyla sequence (Artiodactyla is the order that includes Sus scrofa). This sequence wouldn't be directly recognized if it's not in the reference database, but the reads containing the cryptic sequence might also contain recognizable sequence.
#
# Approach: So, we took the reads that map to the pangenome and sketched them at k=51, and searched them against everything. This notebook processes the results by metagenome x species, and (tries to) summarize them meaningfully.
#
# ## Q2: How taxonomically "pure" are the bacterial pangenomes?
#
# Logic: suppose the pangenome for a species contains a bunch of contigs that belong to _other_ bacterial species. Then some of the reads that map to the pangenome would map to those other species. This certainly occurs to some extent, but how bad is it?
#
# Approach: Take the reads that map to the pangenome and run SingleM on them. Turn the SingleM profile into a JSON file and process it, looking for matches (and mismatches) to the expected species.

# %%
import sys
import argparse
import os
import json
from collections import defaultdict
import pprint

import polars as pl

import taxburst
from taxburst import checks, tree_utils

import glob

ranks = ('superkingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species')

MAPPING_DIR='../outputs.mapping/bams.cds.rand/'

# %%
NOT_EXIST = 1                 # no species/genus level results
MISMATCH = 2                  # dominant family or above mismatch; OR genus and species mismatch
CORRECT_SPECIES_DOM = 3       # correct species is dominant in the read
CORRECT_SPECIES_NONDOM = 4    # correct species is in the reads, but is not dominant
CORRECT_GENUS_MATCH = 5       # correct species not there, but genus is correct

match_types = { NOT_EXIST: 'noexist', MISMATCH: 'mismatch', CORRECT_SPECIES_DOM: 'dom',
               CORRECT_SPECIES_NONDOM: 'nondom', CORRECT_GENUS_MATCH: 'genus' }

gtdb_tax_df = pl.read_csv('../inputs.mapping/names-lineages.csv')


def process_singlem(jsonfile, tax_df, *, verbose=False):
    "process SingleM -> taxburst JSON output, return match type and dominant taxonomic lineage"
    this_species = os.path.basename(jsonfile).split('.')[2]
    
    taxrow = (tax_df.row(named=True,
                         by_predicate=(pl.col("species") == this_species)))
    
    with open(jsonfile, 'rb') as fp:
        tree = json.load(fp)
    nodes = checks.collect_all_nodes(tree)
    if verbose:
        print('===')
    
    rank_vals = {}
    for rank in ranks:
        tracking = defaultdict(int)
        for node in nodes:
            name = node["name"]
            assert name         # don't allow names to be empty             
            assert node["rank"]
    
            if node["rank"] == rank:
                tracking[node["name"]] += node["count"]
    
        if not tracking:
            rank_vals[rank] = (None, None, None)
            continue
    
        total_count = sum(tracking.values())
        tracking = list(sorted(tracking.items(), key=lambda x: -x[1]))
    
        name, frac = tracking[0]
        dominance = frac / total_count
    
        rank_vals[rank] = (name, dominance, name == taxrow[rank])


    # first, check if mismatch at or above family.                          
    for check_rank in ('superkingdom', 'phylum', 'class', 'order', 'family'):
        (name, dom, is_match) = rank_vals[check_rank]
        if name is None:
            #print(f'NO MATCH at {check_rank} for {this_species}')          
            return NOT_EXIST, rank_vals
        if not is_match:
            print(f'MISMATCH: {taxrow[check_rank]} != {name} for {this_species}')
            return MISMATCH, rank_vals


    # second, check match at species:                                       
    check_rank = "species"
    (name, dom, is_match) = rank_vals[check_rank]
    if name is None:        # skip                                          
        pass
    elif is_match:
        if dom >= 0.95:
            return CORRECT_SPECIES_DOM, rank_vals
        else:
            return CORRECT_SPECIES_NONDOM, rank_vals
    else:
        # is genus a match?                                                 
        (genus_name, genus_dom, genus_is_match) = rank_vals["genus"]
        if genus_is_match: # and genus_dom >= 0.95: 
            return CORRECT_GENUS_MATCH, rank_vals
        else:
            print(f'MISMATCH_SP: {taxrow[check_rank]} != {name} for {this_species}')   
            return MISMATCH, rank_vals

    return NOT_EXIST, rank_vals

# %%
# load all available singleM outputs and create a dataframe with the match types
track_xx = []
for jsonfile in glob.glob(MAPPING_DIR + '/*.profile.json'):
    matchtype, rank_vals = process_singlem(jsonfile, gtdb_tax_df)
    basename = os.path.basename(jsonfile)
    acc, _, species, _ = basename.split('.', 3)
    #print(acc, species)
    d = dict(acc=acc, species=species, match_type=match_types[matchtype])
    track_xx.append(d)

singlem_df = pl.DataFrame(track_xx)
# Out:
# MISMATCH_SP: s__Holdemanella porci != s__Floccifex porci for s__Holdemanella porci
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Blautia_A sp018919065 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__Gemmiger qucibialis != s__Faecalibacterium prausnitzii for s__Gemmiger qucibialis
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH: c__Bacilli != c__Bacteroidia for s__Lactobacillus amylovorus
# MISMATCH: c__Bacilli != c__Bacteroidia for s__Lactobacillus amylovorus
# MISMATCH_SP: s__UBA2868 sp004552595 != s__Agathobacter faecis for s__UBA2868 sp004552595
# MISMATCH_SP: s__Gemmiger qucibialis != s__Faecalibacterium prausnitzii for s__Gemmiger qucibialis
# MISMATCH_SP: s__Fimisoma sp002320005 != s__CAG-238 sp945828095 for s__Fimisoma sp002320005
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Blautia_A sp018919065 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__UBA2868 sp004552595 != s__Agathobacter sp000434275 for s__UBA2868 sp004552595
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH_SP: s__UBA2868 sp004552595 != s__CAG-510 sp000434615 for s__UBA2868 sp004552595
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Blautia_A sp003471165 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__Fimisoma sp002320005 != s__CAG-238 sp022787405 for s__Fimisoma sp002320005
# MISMATCH_SP: s__Fimisoma sp002320005 != s__CAG-238 sp945828095 for s__Fimisoma sp002320005
# MISMATCH: f__Ruminococcaceae != f__Oscillospiraceae for s__Gemmiger qucibialis
# MISMATCH_SP: s__Bariatricus sp004560705 != s__Agathobacter sp000434275 for s__Bariatricus sp004560705
# MISMATCH_SP: s__Fimisoma sp002320005 != s__CAG-238 sp945828095 for s__Fimisoma sp002320005
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH_SP: s__Gemmiger qucibialis != s__Gemmiger variabilis_B for s__Gemmiger qucibialis
# MISMATCH_SP: s__JAFBIX01 sp021531895 != s__UBA2868 sp004552595 for s__JAFBIX01 sp021531895
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Agathobacter sp000434275 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__Roseburia inulinivorans != s__Agathobacter sp945971355 for s__Roseburia inulinivorans
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Agathobacter sp000434275 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__Roseburia inulinivorans != s__Blautia_A sp018919065 for s__Roseburia inulinivorans
# MISMATCH_SP: s__UBA2868 sp004552595 != s__Agathobacter sp000434275 for s__UBA2868 sp004552595
# MISMATCH_SP: s__Roseburia inulinivorans != s__Roseburia sp001940165 for s__Roseburia inulinivorans
# MISMATCH_SP: s__UBA2868 sp004552595 != s__Eubacterium_R sp945980375 for s__UBA2868 sp004552595
# MISMATCH_SP: s__Gemmiger qucibialis != s__Faecalibacterium prausnitzii_E for s__Gemmiger qucibialis
# MISMATCH_SP: s__UBA2868 sp004552595 != s__Agathobacter sp000434275 for s__UBA2868 sp004552595
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__UBA2868 sp004552595 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__Holdemanella porci != s__Floccifex porci for s__Holdemanella porci
# MISMATCH: f__Ruminococcaceae != f__Oscillospiraceae for s__Gemmiger qucibialis
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Agathobacter sp000434275 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__UBA2868 sp004552595 != s__Agathobacter sp000434275 for s__UBA2868 sp004552595
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH_SP: s__Fimisoma sp002320005 != s__CAG-238 sp945828095 for s__Fimisoma sp002320005
# MISMATCH_SP: s__Holdemanella porci != s__Floccifex porci for s__Holdemanella porci
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Agathobacter sp945868435 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__Bariatricus sp004560705 != s__W0P33-017 sp004562765 for s__Bariatricus sp004560705
# MISMATCH_SP: s__Bariatricus sp004560705 != s__Agathobacter sp000434275 for s__Bariatricus sp004560705
# MISMATCH_SP: s__JAFBIX01 sp021531895 != s__Dorea formicigenerans for s__JAFBIX01 sp021531895
# MISMATCH_SP: s__Bariatricus sp004560705 != s__JAFBIX01 sp021531895 for s__Bariatricus sp004560705
# MISMATCH: p__Bacillota != p__Bacteroidota for s__Lactobacillus amylovorus
# MISMATCH_SP: s__Gemmiger qucibialis != s__Faecalibacterium wellingii for s__Gemmiger qucibialis
# MISMATCH_SP: s__JAFBIX01 sp021531895 != s__Blautia_A sp003471165 for s__JAFBIX01 sp021531895
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH: f__Ruminococcaceae != f__Oscillospiraceae for s__Gemmiger qucibialis
# MISMATCH_SP: s__Gemmiger qucibialis != s__Faecalibacterium wellingii for s__Gemmiger qucibialis
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH_SP: s__Roseburia inulinivorans != s__Dorea formicigenerans for s__Roseburia inulinivorans
# MISMATCH: c__Bacilli != c__Bacteroidia for s__Lactobacillus amylovorus
# MISMATCH_SP: s__Bariatricus sp004560705 != s__Agathobacter sp000434275 for s__Bariatricus sp004560705
# MISMATCH: f__Ruminococcaceae != f__Oscillospiraceae for s__Gemmiger qucibialis
# MISMATCH_SP: s__Gemmiger qucibialis != s__Faecalibacterium prausnitzii for s__Gemmiger qucibialis
# MISMATCH_SP: s__Bariatricus sp004560705 != s__Oliverpabstia intestinalis for s__Bariatricus sp004560705
# MISMATCH_SP: s__Gemmiger qucibialis != s__Faecalibacterium prausnitzii_E for s__Gemmiger qucibialis
# MISMATCH_SP: s__Roseburia inulinivorans != s__Agathobacter sp000434275 for s__Roseburia inulinivorans
# MISMATCH_SP: s__Roseburia inulinivorans != s__UBA2868 sp004552595 for s__Roseburia inulinivorans
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Agathobacter sp000434275 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__Roseburia inulinivorans != s__Agathobacter sp036311465 for s__Roseburia inulinivorans
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__UBA2868 sp004552595 for s__JALFVM01 sp022787145
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH: f__Ruminococcaceae != f__Aristaeellaceae for s__Gemmiger qucibialis
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__UBA2868 sp004552595 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Clostridium_AP scindens for s__JALFVM01 sp022787145
# MISMATCH_SP: s__UBA2868 sp004552595 != s__Blautia_A sp900066205 for s__UBA2868 sp004552595
# MISMATCH_SP: s__Gemmiger qucibialis != s__Faecalibacterium prausnitzii_E for s__Gemmiger qucibialis
# MISMATCH_SP: s__JAFBIX01 sp021531895 != s__Dorea formicigenerans for s__JAFBIX01 sp021531895
# MISMATCH_SP: s__Gemmiger qucibialis != s__Faecalibacterium taiwanense for s__Gemmiger qucibialis
# MISMATCH_SP: s__Bariatricus sp004560705 != s__Blautia_A sp018919065 for s__Bariatricus sp004560705
# MISMATCH: f__Ruminococcaceae != f__Oscillospiraceae for s__Gemmiger qucibialis
# MISMATCH_SP: s__Roseburia inulinivorans != s__Agathobacter sp000434275 for s__Roseburia inulinivorans
# MISMATCH_SP: s__JAFBIX01 sp021531895 != s__Dorea_A longicatena for s__JAFBIX01 sp021531895
# MISMATCH: p__Bacillota != p__Bacteroidota for s__Lactobacillus amylovorus
# MISMATCH_SP: s__Holdemanella porci != s__Floccifex porci for s__Holdemanella porci
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__UBA2868 sp004552595 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__JAFBIX01 sp021531895 != s__Dorea_A sp016295505 for s__JAFBIX01 sp021531895
# MISMATCH_SP: s__Roseburia inulinivorans != s__UBA2868 sp004552595 for s__Roseburia inulinivorans
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__UBA2868 sp004552595 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Agathobacter sp000434275 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__Roseburia inulinivorans != s__Agathobacter sp000434275 for s__Roseburia inulinivorans
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH_SP: s__UBA2868 sp004552595 != s__Mediterraneibacter faecis for s__UBA2868 sp004552595
# MISMATCH_SP: s__Fimisoma sp002320005 != s__CAG-238 sp022787405 for s__Fimisoma sp002320005
# MISMATCH_SP: s__UBA2868 sp004552595 != s__Agathobacter sp000434275 for s__UBA2868 sp004552595
# MISMATCH_SP: s__Fimisoma sp002320005 != s__Lentihominibacter sp022763735 for s__Fimisoma sp002320005
# MISMATCH: f__Ruminococcaceae != f__Oscillospiraceae for s__Gemmiger qucibialis
# MISMATCH: c__Bacilli != c__Bacteroidia for s__Lactobacillus amylovorus
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH: f__Lactobacillaceae != f__Treponemataceae for s__Lactobacillus amylovorus
# MISMATCH: f__Ruminococcaceae != f__Aristaeellaceae for s__Gemmiger qucibialis
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Bariatricus sp004560705 for s__JALFVM01 sp022787145
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH_SP: s__Fimisoma sp002320005 != s__CAG-238 sp945828095 for s__Fimisoma sp002320005
# MISMATCH_SP: s__Roseburia inulinivorans != s__Agathobacter sp000434275 for s__Roseburia inulinivorans
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH_SP: s__Gemmiger qucibialis != s__Faecalibacterium sp003449675 for s__Gemmiger qucibialis
# MISMATCH_SP: s__Bariatricus sp004560705 != s__Dorea formicigenerans for s__Bariatricus sp004560705
# MISMATCH_SP: s__JAFBIX01 sp021531895 != s__Bariatricus sp004560705 for s__JAFBIX01 sp021531895
# MISMATCH: p__Bacillota != p__Bacteroidota for s__Lactobacillus amylovorus
# MISMATCH_SP: s__Bariatricus sp004560705 != s__Agathobacter sp036311465 for s__Bariatricus sp004560705
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Dorea formicigenerans for s__JALFVM01 sp022787145
# MISMATCH: f__Ruminococcaceae != f__Oscillospiraceae for s__Gemmiger qucibialis
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Agathobacter sp000434275 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__Holdemanella porci != s__Floccifex porci for s__Holdemanella porci
# MISMATCH_SP: s__Bariatricus sp004560705 != s__Agathobacter sp000434275 for s__Bariatricus sp004560705
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Oliverpabstia sp022764165 for s__JALFVM01 sp022787145
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH_SP: s__Roseburia inulinivorans != s__Oliverpabstia intestinalis for s__Roseburia inulinivorans
# MISMATCH_SP: s__JAFBIX01 sp021531895 != s__UBA2868 sp004552595 for s__JAFBIX01 sp021531895
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Blautia_A sp900066205 for s__JALFVM01 sp022787145
# MISMATCH: p__Bacillota != p__Bacteroidota for s__Lactobacillus amylovorus
# MISMATCH: p__Bacillota != p__Bacteroidota for s__Lactobacillus amylovorus
# MISMATCH_SP: s__Gemmiger qucibialis != s__Faecalibacterium wellingii for s__Gemmiger qucibialis
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Blautia_A sp018919065 for s__JALFVM01 sp022787145
# MISMATCH: p__Bacillota != p__Bacteroidota for s__Lactobacillus amylovorus
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__UBA2868 sp004552595 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__Fimisoma sp002320005 != s__CAG-238 sp022787405 for s__Fimisoma sp002320005
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Agathobacter sp000434275 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__Roseburia inulinivorans != s__Agathobacter sp000434275 for s__Roseburia inulinivorans
# MISMATCH_SP: s__Roseburia inulinivorans != s__Agathobacter faecis for s__Roseburia inulinivorans
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Agathobacter sp000434275 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__UBA2868 sp004552595 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__UBA2868 sp004552595 != s__Agathobacter sp945868435 for s__UBA2868 sp004552595
# MISMATCH_SP: s__UBA2868 sp004552595 != s__Eubacterium_R sp900542875 for s__UBA2868 sp004552595
# MISMATCH_SP: s__JAFBIX01 sp021531895 != s__Dorea_A longicatena for s__JAFBIX01 sp021531895
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Blautia_A sp018919065 for s__JALFVM01 sp022787145
# MISMATCH: f__Ruminococcaceae != f__Oscillospiraceae for s__Gemmiger qucibialis
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Blautia_A sp018919065 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__Roseburia inulinivorans != s__Agathobacter sp000434275 for s__Roseburia inulinivorans
# MISMATCH_SP: s__Bariatricus sp004560705 != s__Agathobacter sp945868435 for s__Bariatricus sp004560705
# MISMATCH_SP: s__JAFBIX01 sp021531895 != s__UBA2868 sp004552595 for s__JAFBIX01 sp021531895
# MISMATCH_SP: s__Roseburia inulinivorans != s__JAAYYM01 sp035271065 for s__Roseburia inulinivorans
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Oliverpabstia sp022764165 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__Prevotella sp000434975 != s__Alloprevotella sp022775595 for s__Prevotella sp000434975
# MISMATCH_SP: s__Bariatricus sp004560705 != s__W0P33-017 sp004562765 for s__Bariatricus sp004560705
# MISMATCH_SP: s__Bariatricus sp004560705 != s__Agathobacter sp000434275 for s__Bariatricus sp004560705
# MISMATCH_SP: s__UBA2868 sp004552595 != s__Faecalimonas umbilicata for s__UBA2868 sp004552595
# MISMATCH_SP: s__UBA2868 sp004552595 != s__Agathobacter sp000434275 for s__UBA2868 sp004552595
# MISMATCH_SP: s__Roseburia inulinivorans != s__Agathobacter sp000434275 for s__Roseburia inulinivorans
# MISMATCH_SP: s__Roseburia inulinivorans != s__Agathobacter sp000434275 for s__Roseburia inulinivorans
# MISMATCH_SP: s__Roseburia inulinivorans != s__UBA2868 sp004552595 for s__Roseburia inulinivorans
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Blautia_A sp018919065 for s__JALFVM01 sp022787145
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH_SP: s__Fimisoma sp002320005 != s__CAG-238 sp945828095 for s__Fimisoma sp002320005
# MISMATCH: o__Peptostreptococcales != o__Lachnospirales for s__Mogibacterium_A kristiansenii
# MISMATCH_SP: s__UBA2868 sp004552595 != s__Agathobacter sp000434275 for s__UBA2868 sp004552595
# MISMATCH_SP: s__JAFBIX01 sp021531895 != s__Blautia_A sp018919065 for s__JAFBIX01 sp021531895
# MISMATCH_SP: s__JAFBIX01 sp021531895 != s__Faecalimonas umbilicata for s__JAFBIX01 sp021531895
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Agathobacter sp000434275 for s__JALFVM01 sp022787145
# MISMATCH_SP: s__Roseburia inulinivorans != s__Oliverpabstia sp004562915 for s__Roseburia inulinivorans
# MISMATCH_SP: s__Roseburia inulinivorans != s__UBA2868 sp004552595 for s__Roseburia inulinivorans
# MISMATCH: f__Ruminococcaceae != f__Oscillospiraceae for s__Gemmiger qucibialis
# MISMATCH: f__Muribaculaceae != f__Bacteroidaceae for s__Sodaliphilus sp004557565
# MISMATCH_SP: s__Roseburia inulinivorans != s__Agathobacter sp000434275 for s__Roseburia inulinivorans
# MISMATCH_SP: s__Roseburia inulinivorans != s__Agathobacter sp000434275 for s__Roseburia inulinivorans
# MISMATCH_SP: s__JAFBIX01 sp021531895 != s__Clostridium_AP scindens for s__JAFBIX01 sp021531895
# MISMATCH_SP: s__Fimisoma sp002320005 != s__CAG-238 sp945828095 for s__Fimisoma sp002320005
# MISMATCH_SP: s__UBA2868 sp004552595 != s__Dorea_A sp016295505 for s__UBA2868 sp004552595
# MISMATCH_SP: s__JAFBIX01 sp021531895 != s__JAFBIY01 sp021531975 for s__JAFBIX01 sp021531895
# MISMATCH: f__Ruminococcaceae != f__Oscillospiraceae for s__Gemmiger qucibialis
# MISMATCH_SP: s__UBA2868 sp004552595 != s__Eubacterium_R sp900542875 for s__UBA2868 sp004552595
# MISMATCH_SP: s__JALFVM01 sp022787145 != s__Agathobacter sp000434275 for s__JALFVM01 sp022787145
# MISMATC
# MISMATCH: p__Bacillota != p__Bacteroidota for s__Lactobacillus amylovorus
# MISMATCH_SP: s__Gemmiger qucibialis != s__Faecalibacterium prausnitzii_M for s__Gemmiger qucibialis
# MISMATCH_SP: s__Roseburia inulinivorans != s__Agathobacter sp000434275 for s__Roseburia inulinivorans
# MISMATCH_SP: s__Roseburia inulinivorans != s__Agathobacter sp000434275 for s__Roseburia inulinivorans
# MISMATCH_SP: s__Roseburia inulinivorans != s__Agathobacter sp000434275 for s__Roseburia inulinivorans
# MISMATCH: p__Bacillota != p__Bacteroidota for s__Lactobacillus amylovorus
# MISMATCH: o__Lactobacillales != o__Bacteroidales for s__Lactobacillus amylovorus
# MISMATCH_SP: s__JAFBIX01 sp021531895 != s__UBA2868 sp004552595 for s__JAFBIX01 sp021531895
# MISMATCH: f__Ruminococcaceae != f__Oscillospiraceae for s__Gemmiger qucibialis
# MISMATCH: f__Ruminococcaceae != f__Oscillospiraceae for s__Gemmiger qucibialis
# MISMATCH_SP: s__UBA2868 sp004552595 != s__Eubacterium_R coprostanoligenes for s__UBA2868 sp004552595
# MISMATCH_SP: s__JAFBIX01 sp021531895 != s__Dorea formicigenerans for s__JAFBIX01 sp021531895

# %%
# (there should be 1600 of them)
#assert singlem_df['match_type'].value_counts().sort(by='count')['count'].sum() == 1600
singlem_df['match_type'].value_counts().sort(by='count')
# Out:
# shape: (5, 2)
# ┌────────────┬───────┐
# │ match_type ┆ count │
# │ ---        ┆ ---   │
# │ str        ┆ u32   │
# ╞════════════╪═══════╡
# │ dom        ┆ 133   │
# │ genus      ┆ 200   │
# │ noexist    ┆ 209   │
# │ nondom     ┆ 421   │
# │ mismatch   ┆ 537   │
# └────────────┴───────┘

# %%
def process_gather_lineage(csvfile):
    """Process sourmash gather outputs.
    
    Pull all artiodactyla and some their unique intersect bp; return df, total bp, total weighted bp.
    """
    df = pl.read_csv(csvfile)
    df = df.filter(pl.col("lineage").str.starts_with('Eukaryota;Chordata;Mammalia;Artiodactyla'))

    if df.is_empty():
        return df, 0, 0

    total = df['unique_intersect_bp'].sum()
    total_weight = df['n_unique_weighted_found'].sum() * df['scaled'].unique().to_list()[0]

    return df, total, total_weight

# %%
# find an example none-empty one, just for debugging
for csvfile in glob.glob(MAPPING_DIR + '/*.with-lineages.csv'):
    df, total, total_weight = process_gather_lineage(csvfile)
    if not df.is_empty(): break

print(total, total_weight)
df
# Out:
# 20000 30000
# shape: (1, 33)
# ┌───────────┬───────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ intersect ┆ f_orig_qu ┆ f_match  ┆ f_unique_ ┆ … ┆ n_unique_ ┆ sum_weigh ┆ total_wei ┆ lineage   │
# │ _bp       ┆ ery       ┆ ---      ┆ to_query  ┆   ┆ weighted_ ┆ ted_found ┆ ghted_has ┆ ---       │
# │ ---       ┆ ---       ┆ f64      ┆ ---       ┆   ┆ found     ┆ ---       ┆ hes       ┆ str       │
# │ i64       ┆ f64       ┆          ┆ f64       ┆   ┆ ---       ┆ i64       ┆ ---       ┆           │
# │           ┆           ┆          ┆           ┆   ┆ i64       ┆           ┆ i64       ┆           │
# ╞═══════════╪═══════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 20000     ┆ 0.00173   ┆ 0.000009 ┆ 0.00173   ┆ … ┆ 3         ┆ 4560      ┆ 6678      ┆ Eukaryota │
# │           ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆ ;Chordata │
# │           ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆ ;Mammalia │
# │           ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆ ;Ar…      │
# └───────────┴───────────┴──────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
# load all available sourmash outptus => `smash_df`
track_xx = []
for csvfile in glob.glob(MAPPING_DIR + '/*.with-lineages.csv'):
    df, total, total_weight = process_gather_lineage(csvfile)
    basename = os.path.basename(csvfile)
    acc, _, species, _ = basename.split('.', 3)
    #print(acc, species, len(df))

    d = dict(acc=acc, species=species, euk_bp=total, euk_bp_weighted=total_weight)
    track_xx.append(d)

smash_df = pl.DataFrame(track_xx)

# %%
# expect 1600
#assert len(smash_df) == 1600
smash_df.sort(by='euk_bp', descending=True)
# Out:
# shape: (1_500, 4)
# ┌─────────────┬─────────────────────────────────┬─────────┬─────────────────┐
# │ acc         ┆ species                         ┆ euk_bp  ┆ euk_bp_weighted │
# │ ---         ┆ ---                             ┆ ---     ┆ ---             │
# │ str         ┆ str                             ┆ i64     ┆ i64             │
# ╞═════════════╪═════════════════════════════════╪═════════╪═════════════════╡
# │ SRR14369134 ┆ s__Lactobacillus amylovorus     ┆ 1930000 ┆ 4180000         │
# │ SRR14369219 ┆ s__Lactobacillus amylovorus     ┆ 1370000 ┆ 2470000         │
# │ SRR11489750 ┆ s__Lactobacillus amylovorus     ┆ 1300000 ┆ 2660000         │
# │ SRR14369134 ┆ s__Holdemanella porci           ┆ 1240000 ┆ 1340000         │
# │ SRR14369296 ┆ s__Lactobacillus amylovorus     ┆ 1110000 ┆ 1870000         │
# │ …           ┆ …                               ┆ …       ┆ …               │
# │ ERR1135349  ┆ s__Cryptobacteroides sp9005469… ┆ 0       ┆ 0               │
# │ SRR8655118  ┆ s__Cryptobacteroides sp9005469… ┆ 0       ┆ 0               │
# │ ERR1135303  ┆ s__Prevotella sp000434975       ┆ 0       ┆ 0               │
# │ ERR1135213  ┆ s__Prevotella sp002251295       ┆ 0       ┆ 0               │
# │ SRR14369219 ┆ s__Phascolarctobacterium_A suc… ┆ 0       ┆ 0               │
# └─────────────┴─────────────────────────────────┴─────────┴─────────────────┘

# %%
# awesome, join the dataframes to produce a single main dataframe that 
# contains metagenome x species summaries of both sourmash and singleM output
join_df = smash_df.join(singlem_df, on=['acc', 'species'], how='inner')
join_df.sort(by='euk_bp_weighted', descending=True)
# Out:
# shape: (1_500, 5)
# ┌─────────────┬─────────────────────────────┬─────────┬─────────────────┬────────────┐
# │ acc         ┆ species                     ┆ euk_bp  ┆ euk_bp_weighted ┆ match_type │
# │ ---         ┆ ---                         ┆ ---     ┆ ---             ┆ ---        │
# │ str         ┆ str                         ┆ i64     ┆ i64             ┆ str        │
# ╞═════════════╪═════════════════════════════╪═════════╪═════════════════╪════════════╡
# │ SRR14369134 ┆ s__Sodaliphilus sp004557565 ┆ 410000  ┆ 9060000         ┆ nondom     │
# │ SRR11489750 ┆ s__Sodaliphilus sp004557565 ┆ 180000  ┆ 5200000         ┆ mismatch   │
# │ SRR14369134 ┆ s__Lactobacillus amylovorus ┆ 1930000 ┆ 4180000         ┆ genus      │
# │ SRR14369268 ┆ s__Sodaliphilus sp004557565 ┆ 250000  ┆ 3080000         ┆ mismatch   │
# │ SRR11489750 ┆ s__Lactobacillus amylovorus ┆ 1300000 ┆ 2660000         ┆ mismatch   │
# │ …           ┆ …                           ┆ …       ┆ …               ┆ …          │
# │ SRR11551377 ┆ s__Bariatricus sp004560705  ┆ 0       ┆ 0               ┆ nondom     │
# │ SRR17241521 ┆ s__Fimisoma sp002320005     ┆ 0       ┆ 0               ┆ nondom     │
# │ SRR8960379  ┆ s__JAFBIX01 sp021531895     ┆ 0       ┆ 0               ┆ mismatch   │
# │ SRR11183981 ┆ s__Gemmiger qucibialis      ┆ 0       ┆ 0               ┆ nondom     │
# │ ERR3211964  ┆ s__Prevotella sp002251295   ┆ 0       ┆ 0               ┆ genus      │
# └─────────────┴─────────────────────────────┴─────────┴─────────────────┴────────────┘

# %% [markdown]
# ## Summarize

# %%
best_species = ['s__Mogibacterium_A kristiansenii',
                's__Phascolarctobacterium_A succinatutens',
                's__Cryptobacteroides sp900546925',
                's__Holdemanella porci']

summary = []
#for species in best_species:
for species in join_df['species'].unique():

    sub_df = join_df.filter(pl.col("species") == species)
    assert len(sub_df) == 100
    dd = {}
    for d in sub_df['match_type'].value_counts().to_dicts():
        dd[d['match_type']] = d['count']

    euk_bp = sum(sub_df['euk_bp'])
    euk_bp_weighted = sum(sub_df['euk_bp_weighted'])
    euk_freq = len(sub_df.filter(pl.col("euk_bp") > 10_000))
    summary.append((euk_bp, euk_bp_weighted, species, dd, euk_freq / len(sub_df)))
    #print(species, dd)
    #print(sum(sub_df['euk_bp']) / 10_000)

print('** summary by species, sorted by amount of estimate pig overlap:\n')
summary.sort()
for euk_bp, euk_bp_weighted, species, dd, euk_freq in summary:
    s = " ".join(f"{k}={v}" for (k, v) in sorted(dd.items()) )
    print(f"{euk_bp:>9d} {euk_bp_weighted:>9d}  {euk_freq:.2f} {species:<41} {s}")

print('')
print('** summary by species, sorted by number of singleM mismatches:\n')
summary.sort(key=lambda x: x[3].get('mismatch', 0))
for euk_bp, euk_bp_weighted, species, dd, euk_freq in summary:
    s = " ".join(f"{k}={v}" for (k, v) in sorted(dd.items()) )
    print(f"{euk_bp:>9d} {euk_bp_weighted:>9d}  {euk_freq:.2f} {species:<41} {s}")
# Out:
# ** summary by species, sorted by amount of estimate pig overlap:
#
#     10000     30000  0.00 s__Fimisoma sp002320005                   dom=13 mismatch=39 noexist=20 nondom=28
#     50000     70000  0.00 s__JALFVM01 sp022787145                   dom=1 genus=1 mismatch=85 noexist=8 nondom=5
#     80000     90000  0.01 s__Prevotella sp002251295                 dom=6 genus=37 mismatch=5 noexist=6 nondom=46
#     90000    120000  0.02 s__Phascolarctobacterium_A succinatutens  dom=21 genus=31 noexist=4 nondom=44
#    100000    110000  0.02 s__Bariatricus sp004560705                dom=2 mismatch=53 noexist=5 nondom=40
#    100000    110000  0.02 s__Cryptobacteroides sp900546925          dom=4 genus=30 noexist=13 nondom=53
#    110000    130000  0.02 s__JAFBIX01 sp021531895                   dom=1 mismatch=47 noexist=37 nondom=15
#    120000    150000  0.03 s__Roseburia inulinivorans                genus=1 mismatch=88 noexist=7 nondom=4
#    130000    140000  0.03 s__Gemmiger qucibialis                    genus=19 mismatch=56 noexist=7 nondom=18
#    180000    210000  0.03 s__UBA2868 sp004552595                    dom=14 mismatch=52 noexist=5 nondom=29
#    340000    430000  0.06 s__Mogibacterium_A kristiansenii          dom=48 mismatch=1 noexist=51
#   1220000   1460000  0.17 s__Prevotella sp000434975                 dom=1 genus=53 mismatch=4 noexist=10 nondom=32
#   3390000  49850000  0.47 s__Sodaliphilus sp004557565               dom=14 genus=1 mismatch=57 noexist=4 nondom=24
#   7780000   8600000  0.32 s__Holdemanella porci                     dom=8 genus=15 mismatch=12 noexist=31 nondom=34
#  14430000  27360000  0.44 s__Lactobacillus amylovorus               genus=12 mismatch=38 noexist=1 nondom=49
#
# ** summary by species, sorted by number of singleM mismatches:
#
#     90000    120000  0.02 s__Phascolarctobacterium_A succinatutens  dom=21 genus=31 noexist=4 nondom=44
#    100000    110000  0.02 s__Cryptobacteroides sp900546925          dom=4 genus=30 noexist=13 nondom=53
#    340000    430000  0.06 s__Mogibacterium_A kristiansenii          dom=48 mismatch=1 noexist=51
#   1220000   1460000  0.17 s__Prevotella sp000434975                 dom=1 genus=53 mismatch=4 noexist=10 nondom=32
#     80000     90000  0.01 s__Prevotella sp002251295                 dom=6 genus=37 mismatch=5 noexist=6 nondom=46
#   7780000   8600000  0.32 s__Holdemanella porci                     dom=8 genus=15 mismatch=12 noexist=31 nondom=34
#  14430000  27360000  0.44 s__Lactobacillus amylovorus               genus=12 mismatch=38 noexist=1 nondom=49
#     10000     30000  0.00 s__Fimisoma sp002320005                   dom=13 mismatch=39 noexist=20 nondom=28
#    110000    130000  0.02 s__JAFBIX01 sp021531895                   dom=1 mismatch=47 noexist=37 nondom=15
#    180000    210000  0.03 s__UBA2868 sp004552595                    dom=14 mismatch=52 noexist=5 nondom=29
#    100000    110000  0.02 s__Bariatricus sp004560705                dom=2 mismatch=53 noexist=5 nondom=40
#    130000    140000  0.03 s__Gemmiger qucibialis                    genus=19 mismatch=56 noexist=7 nondom=18
#   3390000  49850000  0.47 s__Sodaliphilus sp004557565               dom=14 genus=1 mismatch=57 noexist=4 nondom=24
#     50000     70000  0.00 s__JALFVM01 sp022787145                   dom=1 genus=1 mismatch=85 noexist=8 nondom=5
#    120000    150000  0.03 s__Roseburia inulinivorans                genus=1 mismatch=88 noexist=7 nondom=4

# %% [markdown]
# ## Some interim conclusions
#
# (NEEDS TO BE UPDATED FOR CDS)
#
# These four have few mismatches (good taxonomic purity), and relatively little pig sequence:
# * s__Phascolarctobacterium_A succinatutens
# * s__Cryptobacteroides sp900546925
# * s__Mogibacterium_A kristiansenii
# * s__Prevotella sp002251295
#
# These have relatively few mismatches, and more pig sequence:
# * s__Prevotella sp000434975
# * s__Holdemanella porci
#
# Not great:
# * s__Fimisoma sp002320005 - some mismatches, very little pig
# * s__Roseburia inulinivorans - _many_ mismatches, not much pig
# * s__Gemmiger qucibialis - _many_ mismatches, lotsa pig
# * s__Bariatricus sp004560705 - _many_ mismatches
# * s__UBA2868 sp004552595 - many mismatches
#
# LOTS of mismatches:
# * s__JALFVM01 sp022787145 - _many_ mismatches
# * s__JAFBIX01 sp021531895
#
# Terrible:
# * s__Phocaeicola vulgatus - MANY mismatches, lotsa pig
# * s__Lactobacillus amylovorus - _many_ mismatches, lots of pig
# * s__Sodaliphilus sp004557565
